# %%
import pandas as pd
rent_df = pd.read_csv('ACS_11_16_Median_Gross_Rent.csv', header=[1])
rent_df = rent_df.drop(columns=['Id', 'Geography', 'Margin of Error; Median gross rent'])
rent_df = rent_df.drop(columns=['Margin of Error; Median gross rent.{}'.format(i) for i in range(1,6)])
rent_df.head()
type(rent_df)
# Out:
# pandas.core.frame.DataFrame

# %%
rent_df.rename(index=str, columns={'Estimate; Median gross rent': '2016 Median Gross Rent', 'Estimate; Median gross rent.1': '2015 Median Gross Rent', 'Estimate; Median gross rent.2':'2014 Median Gross Rent', 'Estimate; Median gross rent.3':'2013 Median Gross Rent', 'Estimate; Median gross rent.4':'2012 Median Gross Rent', 'Estimate; Median gross rent.5':'2011 Median Gross Rent'})
# Out:
#         Id2 2016 Median Gross Rent 2015 Median Gross Rent  \
# 0     10001                   2114                   1989
# 1     10002                    919                    882
# 2     10003                   2117                   2030
# 3     10004                   2911                   2851
# 4     10005                   3005                   2918
# 5     10006                   2847                   2824
# 6     10007                   3339                   3423
# 7     10009                   1554                   1485
# 8     10010                   2442                   2295
# 9     10011                   2029                   2000
# 10    10012                   2128                   2027
# 11    10013                   1663                   1512
# 12    10014                   2337                   2281
# 13    10016                   2440                   2327
# 14    10017                   2214                   2218
# ...
