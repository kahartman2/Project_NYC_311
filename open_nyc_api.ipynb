# %%
import requests
import pandas as pd
import json
#created_date=2014-04& created_date=2014-04&borough=QUEENS' created_date=2014&agency=NYPD

# %%
# client = Socrata("data.cityofnewyork.us", None)
# results = client.get("fhrw-4uyv", limit=2000)
open_nyc = requests.get('https://data.cityofnewyork.us/resource/fhrw-4uyv.json?created_date=2016-01-08T00:00:00.000').json()
len(open_nyc)
# Out:
# 81

# %%
open_nyc_df = pd.DataFrame.from_records(open_nyc)

# %%
open_nyc_df
# Out:
#     address_type agency                              agency_name         bbl  \
# 0   INTERSECTION  DOHMH  Department of Health and Mental Hygiene         NaN
# 1        LATLONG  DOHMH  Department of Health and Mental Hygiene         NaN
# 2        ADDRESS  DOHMH  Department of Health and Mental Hygiene  4006300041
# 3        ADDRESS  DOHMH  Department of Health and Mental Hygiene  4078990014
# 4        ADDRESS  DOHMH  Department of Health and Mental Hygiene  3065680015
# 5        ADDRESS  DOHMH  Department of Health and Mental Hygiene  4085920063
# 6        LATLONG  DOHMH  Department of Health and Mental Hygiene         NaN
# 7        ADDRESS  DOHMH  Department of Health and Mental Hygiene  1018800053
# 8        ADDRESS  DOHMH  Department of Health and Mental Hygiene  4008410060
# 9        LATLONG  DOHMH  Department of Health and Mental Hygiene         NaN
# 10       ADDRESS  DOHMH  Department of Health and Mental Hygiene  3015990056
# ...

# %%
open_nyc_df.to_csv('open_nyc_data')
